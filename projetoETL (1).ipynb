# %% [markdown]
# ### Bibliotecas Utilizadas

# %%
import pandas as pd
from IPython.display import Image
from google.oauth2 import service_account
from pandas.io import gbq

# %% [markdown]
# ### Extração de Dados

# %%
contratos = pd.read_csv('/tabela_contratos.csv')

# %%
contratos
# Out:
#      id_contrato nome_contrato  \
# 0              1       13/2012
# 1              2  Disp. Lic. 1
# 2              3  Disp. Lic. 2
# 3              4       32/2014
# 4              5      001/2014
# ..           ...           ...
# 179          180       13/2020
# 180          181      009/2018
# 181          182       16/2020
# 182          183       18/2020
# 183          184       20/2020
#
#                                        objeto_contrato  valor_contrato  \
# 0    Contratação de Empresa para Ministrar Curso de...        94947.23
# 1          Prestação de serviço na confecção de Chaves         5234.00
# 2        Prestação de serviço na confecção de Carimbos         1800.00
# 3                           Serviço de Telefônia Móvel        73915.08
# 4               Publicações no Diário Oficial da União        45000.00
# ..                                                 ...             ...
# 179  Contratação de serviços ofertados pelo SESI/Si...       134211.84
# 180   Serviços de Suporte Tecnológico ao Ambiente d...      2107768.42
# 181               Aquisição e Instalação de divisórias      5541773.00
# 182  Manutenção Preventiva e corretiva dos elevador...         9600.00
# 183         Contratação de Serviço comum de engenharia       102600.00
#
#      inicio_vigencia  termino_vigencia  fk_empresa_contratada
# 0                  4                32                      1
# 1                 13                33                      2
# 2                 10                33                      3
# 3                  6                33                      4
# 4                  8                35                      5
# ..               ...               ...                    ...
# 179              208               243                     65
# 180              209               244                     17
# 181              212               246                     66
# 182              213               247                     67
# 183              214               248                     68
#
# [184 rows x 7 columns]

# %%
datas = pd.read_csv('/tabela_datas.csv')
datas
# Out:
#      id_data        data
# 0          1  20/05/2014
# 1          2  27/09/2014
# 2          3  28/11/2014
# 3          4  20/12/2014
# 4          5  28/12/2014
# ..       ...         ...
# 249      250  24/10/2019
# 250      251  24/10/2020
# 251      252  05/11/2020
# 252      253  23/01/2020
# 253      254  31/09/2017
#
# [254 rows x 2 columns]

# %%
empresas = pd.read_csv('/tabela_empresas.csv')
empresas
# Out:
#     id_empresa       nome_empresa
# 0            1   Thomas Jefferson
# 1            2      Chaveiro City
# 2            3       HBL Carimbos
# 3            4          Claro S/A
# 4            5  Imprensa Nacional
# ..         ...                ...
# 63          64     Nara Comercial
# 64          65            SESI-DF
# 65          66              FORMA
# 66          67      IG Elevadores
# 67          68  Serôa Construtora
#
# [68 rows x 2 columns]

# %% [markdown]
# ### Transformação dos Dados

# %%
contratos_mod = contratos.merge(empresas,
                                 left_on = 'fk_empresa_contratada',
                                 right_on = 'id_empresa',
                                 how = 'left')

# %%
contratos_mod
# Out:
#      id_contrato nome_contrato  \
# 0              1       13/2012
# 1              2  Disp. Lic. 1
# 2              3  Disp. Lic. 2
# 3              4       32/2014
# 4              5      001/2014
# ..           ...           ...
# 179          180       13/2020
# 180          181      009/2018
# 181          182       16/2020
# 182          183       18/2020
# 183          184       20/2020
#
#                                        objeto_contrato  valor_contrato  \
# 0    Contratação de Empresa para Ministrar Curso de...        94947.23
# 1          Prestação de serviço na confecção de Chaves         5234.00
# 2        Prestação de serviço na confecção de Carimbos         1800.00
# 3                           Serviço de Telefônia Móvel        73915.08
# 4               Publicações no Diário Oficial da União        45000.00
# ..                                                 ...             ...
# 179  Contratação de serviços ofertados pelo SESI/Si...       134211.84
# 180   Serviços de Suporte Tecnológico ao Ambiente d...      2107768.42
# 181               Aquisição e Instalação de divisórias      5541773.00
# 182  Manutenção Preventiva e corretiva dos elevador...         9600.00
# 183         Contratação de Serviço comum de engenharia       102600.00
#
#      inicio_vigencia  termino_vigencia  fk_empresa_contratada  id_empresa  \
# 0                  4                32                      1           1
# 1                 13                33                      2           2
# 2                 10                33                      3           3
# 3                  6                33                      4           4
# 4                  8                35                      5           5
# ..               ...               ...                    ...         ...
# 179              208               243                     65          65
# 180              209               244                     17          17
# 181              212               246                     66          66
# 182              213               247                     67          67
# 183              214               248                     68          68
#
#           nome_empresa
# 0     Thomas Jefferson
# 1        Chaveiro City
# 2         HBL Carimbos
# 3            Claro S/A
# 4    Imprensa Nacional
# ..                 ...
# 179            SESI-DF
# 180         Central IT
# 181              FORMA
# 182      IG Elevadores
# 183  Serôa Construtora
#
# [184 rows x 9 columns]

# %%
contratos_mod.drop(columns = ['fk_empresa_contratada' , 'id_empresa'], inplace=True)

# %%
contratos_mod.head(10)
# Out:
#    id_contrato nome_contrato  \
# 0            1       13/2012
# 1            2  Disp. Lic. 1
# 2            3  Disp. Lic. 2
# 3            4       32/2014
# 4            5      001/2014
# 5            6      002/2014
# 6            7      003/2012
# 7            8      001/2015
# 8            9         42064
# 9           10  Disp. Lic. 3
#
#                                      objeto_contrato  valor_contrato  \
# 0  Contratação de Empresa para Ministrar Curso de...        94947.23
# 1        Prestação de serviço na confecção de Chaves         5234.00
# 2      Prestação de serviço na confecção de Carimbos         1800.00
# 3                         Serviço de Telefônia Móvel        73915.08
# 4             Publicações no Diário Oficial da União        45000.00
# 5                 Prestação de serviço de Copeiragem       385986.11
# 6           Manutenção Preventiva e Evolutiva Próton        47493.72
# 7  Bilhetes de passagens aéreas, reservas, emissã...       380574.23
# 8                         Apoio administrativo 1 e 2      2043582.72
# 9                       Assinatura do Jornal O Globo         1248.00
#
#    inicio_vigencia  termino_vigencia       nome_empresa
# 0                4                32   Thomas Jefferson
# 1               13                33      Chaveiro City
# 2               10                33       HBL Carimbos
# 3                6                33          Claro S/A
# 4                8                35  Imprensa Nacional
# 5                9                36                3 R
# 6               11                39              IKHON
# 7               12                41            Aerotur
# 8               14                43      Sempre Alerta
# 9               15                45          Infoglobo

# %%
contratos_final = contratos.merge(datas,
                                 left_on = 'inicio_vigencia',
                                 right_on = 'id_data',
                                 how = 'left')
contratos_final
# Out:
#      id_contrato nome_contrato  \
# 0              1       13/2012
# 1              2  Disp. Lic. 1
# 2              3  Disp. Lic. 2
# 3              4       32/2014
# 4              5      001/2014
# ..           ...           ...
# 179          180       13/2020
# 180          181      009/2018
# 181          182       16/2020
# 182          183       18/2020
# 183          184       20/2020
#
#                                        objeto_contrato  valor_contrato  \
# 0    Contratação de Empresa para Ministrar Curso de...        94947.23
# 1          Prestação de serviço na confecção de Chaves         5234.00
# 2        Prestação de serviço na confecção de Carimbos         1800.00
# 3                           Serviço de Telefônia Móvel        73915.08
# 4               Publicações no Diário Oficial da União        45000.00
# ..                                                 ...             ...
# 179  Contratação de serviços ofertados pelo SESI/Si...       134211.84
# 180   Serviços de Suporte Tecnológico ao Ambiente d...      2107768.42
# 181               Aquisição e Instalação de divisórias      5541773.00
# 182  Manutenção Preventiva e corretiva dos elevador...         9600.00
# 183         Contratação de Serviço comum de engenharia       102600.00
#
#      inicio_vigencia  termino_vigencia  fk_empresa_contratada  id_data  \
# 0                  4                32                      1        4
# 1                 13                33                      2       13
# 2                 10                33                      3       10
# 3                  6                33                      4        6
# 4                  8                35                      5        8
# ..               ...               ...                    ...      ...
# 179              208               243                     65      208
# 180              209               244                     17      209
# 181              212               246                     66      212
# 182              213               247                     67      213
# 183              214               248                     68      214
#
#            data
# 0    20/12/2014
# 1    26/02/2015
# 2    10/02/2015
# 3    01/01/2015
# 4    27/01/2015
# ..          ...
# 179  24/07/2020
# 180  27/07/2020
# 181  19/08/2020
# 182  31/08/2020
# 183  08/09/2020
#
# [184 rows x 9 columns]

# %%
contratos_final.drop(columns = ['inicio_vigencia' , 'id_data'], inplace=True)

# %%
contratos_final.rename(columns = {'data':'data_inicio_vigencia'}, inplace=True)

# %%
contratos_final.head(10)
# Out:
#    id_contrato nome_contrato  \
# 0            1       13/2012
# 1            2  Disp. Lic. 1
# 2            3  Disp. Lic. 2
# 3            4       32/2014
# 4            5      001/2014
# 5            6      002/2014
# 6            7      003/2012
# 7            8      001/2015
# 8            9         42064
# 9           10  Disp. Lic. 3
#
#                                      objeto_contrato  valor_contrato  \
# 0  Contratação de Empresa para Ministrar Curso de...        94947.23
# 1        Prestação de serviço na confecção de Chaves         5234.00
# 2      Prestação de serviço na confecção de Carimbos         1800.00
# 3                         Serviço de Telefônia Móvel        73915.08
# 4             Publicações no Diário Oficial da União        45000.00
# 5                 Prestação de serviço de Copeiragem       385986.11
# 6           Manutenção Preventiva e Evolutiva Próton        47493.72
# 7  Bilhetes de passagens aéreas, reservas, emissã...       380574.23
# 8                         Apoio administrativo 1 e 2      2043582.72
# 9                       Assinatura do Jornal O Globo         1248.00
#
#    termino_vigencia  fk_empresa_contratada data_inicio_vigencia
# 0                32                      1           20/12/2014
# 1                33                      2           26/02/2015
# 2                33                      3           10/02/2015
# 3                33                      4           01/01/2015
# 4                35                      5           27/01/2015
# 5                36                      6           28/01/2015
# 6                39                      7           14/02/2015
# 7                41                      8           25/02/2015
# 8                43                      9           05/03/2015
# 9                45                     10           18/03/2015

# %%
contratos_final_2 = contratos_final.merge(datas,
                                 left_on = 'termino_vigencia',
                                 right_on = 'id_data',
                                 how = 'left')

# %%
contratos_final_2.drop(columns = ['termino_vigencia' , 'id_data'], inplace=True)

# %%
contratos_final_2.rename(columns = {'data':'data_termino_vigencia'}, inplace=True)

# %%
contratos_final_2
# Out:
#      id_contrato nome_contrato  \
# 0              1       13/2012
# 1              2  Disp. Lic. 1
# 2              3  Disp. Lic. 2
# 3              4       32/2014
# 4              5      001/2014
# ..           ...           ...
# 179          180       13/2020
# 180          181      009/2018
# 181          182       16/2020
# 182          183       18/2020
# 183          184       20/2020
#
#                                        objeto_contrato  valor_contrato  \
# 0    Contratação de Empresa para Ministrar Curso de...        94947.23
# 1          Prestação de serviço na confecção de Chaves         5234.00
# 2        Prestação de serviço na confecção de Carimbos         1800.00
# 3                           Serviço de Telefônia Móvel        73915.08
# 4               Publicações no Diário Oficial da União        45000.00
# ..                                                 ...             ...
# 179  Contratação de serviços ofertados pelo SESI/Si...       134211.84
# 180   Serviços de Suporte Tecnológico ao Ambiente d...      2107768.42
# 181               Aquisição e Instalação de divisórias      5541773.00
# 182  Manutenção Preventiva e corretiva dos elevador...         9600.00
# 183         Contratação de Serviço comum de engenharia       102600.00
#
#      fk_empresa_contratada data_inicio_vigencia data_termino_vigencia
# 0                        1           20/12/2014            19/12/2015
# 1                        2           26/02/2015            31/12/2015
# 2                        3           10/02/2015            31/12/2015
# 3                        4           01/01/2015            31/12/2015
# 4                        5           27/01/2015            26/01/2016
# ..                     ...                  ...                   ...
# 179                     65           24/07/2020            24/07/2021
# 180                     17           27/07/2020            27/07/2021
# 181                     66           19/08/2020            19/08/2021
# 182                     67           31/08/2020            31/08/2021
# 183                     68           08/09/2020            08/09/2021
#
# [184 rows x 7 columns]

# %%
contratos_final_2.count()
# Out:
# id_contrato              184
# nome_contrato            184
# objeto_contrato          184
# valor_contrato           184
# fk_empresa_contratada    184
# data_inicio_vigencia     184
# data_termino_vigencia    184
# dtype: int64

# %%
contratos_final_2.dtypes
# Out:
# id_contrato                int64
# nome_contrato             object
# objeto_contrato           object
# valor_contrato           float64
# fk_empresa_contratada      int64
# data_inicio_vigencia      object
# data_termino_vigencia     object
# dtype: object

# %%
contratos_final_2.data_inicio_vigencia = pd.to_datetime(contratos_final_2.data_inicio_vigencia, format = '%d/%m/%Y').dt.date

# %%
contratos_final_2.data_termino_vigencia = pd.to_datetime(contratos_final_2.data_termino_vigencia, format = '%d/%m/%Y').dt.date
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-949c9a7b765e> in <cell line: 1>()
# ----> 1 contratos_final_2.data_termino_vigencia = pd.to_datetime(contratos_final_2.data_termino_vigencia, format = '%d/%m/%Y').dt.date
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066             result = arg.map(cache_array)
#    1067         else:
# -> 1068             values = convert_listlike(arg._values, format)
#    1069             result = arg._constructor(values, index=arg.index, name=arg.name)
#    1070     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     428
#     429     if format is not None:
# --> 430         res = _to_datetime_with_format(
#     431             arg, orig_arg, name, tz, format, exact, errors, infer_datetime_format
#     432         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     536
#     537     # fallback
# --> 538     res = _array_strptime_with_fallback(
#     539         arg, name, tz, fmt, exact, errors, infer_datetime_format
#     540     )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in _array_strptime_with_fallback(arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     471
#     472     try:
# --> 473         result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors)
#     474     except OutOfBoundsDatetime:
#     475         if errors == "raise":
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/tslibs/strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/tslibs/strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: day is out of range for month

# %%
for i in contratos_final_2.data_termino_vigencia:
    print(i)
    print(pd.to_datetime(i))
# Out:
# 19/12/2015
# 2015-12-19 00:00:00
# 31/12/2015
# 2015-12-31 00:00:00
# 31/12/2015
# 2015-12-31 00:00:00
# 31/12/2015
# 2015-12-31 00:00:00
# 26/01/2016
# 2016-01-26 00:00:00
# 27/01/2016
# 2016-01-27 00:00:00
# 13/02/2016
# 2016-02-13 00:00:00
# 24/02/2016
# 2016-02-24 00:00:00
# 04/03/2016
# 2016-04-03 00:00:00
# 17/03/2016
# 2016-03-17 00:00:00
# 22/03/2016
# 2016-03-22 00:00:00
# 03/04/2016
# 2016-03-04 00:00:00
# 04/04/2016
# 2016-04-04 00:00:00
# 09/04/2016
# 2016-09-04 00:00:00
# 23/04/2016
# 2016-04-23 00:00:00
# 19/05/2016
# 2016-05-19 00:00:00
# 14/07/2016
# 2016-07-14 00:00:00
# 03/08/2016
# 2016-03-08 00:00:00
# 31/08/2016
# 2016-08-31 00:00:00
# 31/08/2016
# 2016-08-31 00:00:00
# 26/09/2016
# 2016-09-26 00:00:00
# 04/10/2016
# 2016-04-10 00:00:00
# 26/10/2016
# 2016-10-26 00:00:00
# 06/11/2016
# 2016-06-11 00:00:00
# 05/12/2016
# 2016-05-12 00:00:00
# 07/12/2016
# 2016-07-12 00:00:00
# 06/01/2017
# 2017-06-01 00:00:00
# 11/05/2017
# 2017-11-05 00:00:00
# 25/05/2017
# 2017-05-25 00:00:00
# 27/11/2017
# 2017-11-27 00:00:00
# 27/12/2017
# 2017-12-27 00:00:00
# 03/12/2016
# 2016-03-12 00:00:00
# 05/12/2016
# 2016-05-12 00:00:00
# 07/12/2016
# 2016-07-12 00:00:00
# 31/12/2016
# 2016-12-31 00:00:00
# 31/12/2016
# 2016-12-31 00:00:00
# 06/01/2017
# 2017-06-01 00:00:00
# 27/01/2017
# 2017-01-27 00:00:00
# 28/01/2017
# 2017-01-28 00:00:00
# 14/02/2017
# 2017-02-14 00:00:00
# 25/02/2017
# 2017-02-25 00:00:00
# 25/02/2017
# 2017-02-25 00:00:00
# 18/03/2017
# 2017-03-18 00:00:00
# 05/03/2017
# 2017-05-03 00:00:00
# 23/03/2017
# 2017-03-23 00:00:00
# 04/04/2017
# 2017-04-04 00:00:00
# 05/04/2017
# 2017-05-04 00:00:00
# 10/04/2017
# 2017-10-04 00:00:00
# 24/04/2017
# 2017-04-24 00:00:00
# 01/05/2017
# 2017-01-05 00:00:00
# 11/05/2017
# 2017-11-05 00:00:00
# 25/05/2017
# 2017-05-25 00:00:00
# 31/05/2017
# 2017-05-31 00:00:00
# 15/07/2016
# 2016-07-15 00:00:00
# 03/08/2017
# 2017-03-08 00:00:00
# 31/08/2017
# 2017-08-31 00:00:00
# 31/09/2017
# <ipython-input-26-c1a1f3f539ea>:3: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   print(pd.to_datetime(i))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing._parse_delimited_date()
#
# datetime.pxd in cpython.datetime.datetime_new()
#
# ValueError: day is out of range for month
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime for "31/09/2017" at position 0
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-c1a1f3f539ea> in <cell line: 1>()
#       1 for i in contratos_final_2.data_termino_vigencia:
#       2     print(i)
# ----> 3     print(pd.to_datetime(i))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1100             result = convert_listlike(argc, format)
#    1101     else:
# -> 1102         result = convert_listlike(np.array([arg]), format)[0]
#    1103         if isinstance(arg, bool) and isinstance(result, np.bool_):
#    1104             result = bool(result)  # TODO: avoid this kludge.
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     436     assert format is None or infer_datetime_format
#     437     utc = tz == "utc"
# --> 438     result, tz_parsed = objects_to_datetime64ns(
#     439         arg,
#     440         dayfirst=dayfirst,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2175     order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2176     try:
# -> 2177         result, tz_parsed = tslib.array_to_datetime(
#    2178             data.ravel("K"),
#    2179             errors=errors,
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib._array_to_datetime_object()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib._array_to_datetime_object()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing._parse_delimited_date()
#
# datetime.pxd in cpython.datetime.datetime_new()
#
# ValueError: day is out of range for month present at position 0

# %%
contratos_final_2.data_termino_vigencia = contratos_final_2.data_termino_vigencia.str.replace('31/09/2017','30/09/2017')

# %%
contratos_final_2.data_termino_vigencia = pd.to_datetime(contratos_final_2.data_termino_vigencia, format = '%d/%m/%Y').dt.date

# %%
contratos_final_2.dtypes
# Out:
# id_contrato                int64
# nome_contrato             object
# objeto_contrato           object
# valor_contrato           float64
# fk_empresa_contratada      int64
# data_inicio_vigencia      object
# data_termino_vigencia     object
# dtype: object

# %%
contratos_final_2.head(10)
# Out:
#    id_contrato nome_contrato  \
# 0            1       13/2012
# 1            2  Disp. Lic. 1
# 2            3  Disp. Lic. 2
# 3            4       32/2014
# 4            5      001/2014
# 5            6      002/2014
# 6            7      003/2012
# 7            8      001/2015
# 8            9         42064
# 9           10  Disp. Lic. 3
#
#                                      objeto_contrato  valor_contrato  \
# 0  Contratação de Empresa para Ministrar Curso de...        94947.23
# 1        Prestação de serviço na confecção de Chaves         5234.00
# 2      Prestação de serviço na confecção de Carimbos         1800.00
# 3                         Serviço de Telefônia Móvel        73915.08
# 4             Publicações no Diário Oficial da União        45000.00
# 5                 Prestação de serviço de Copeiragem       385986.11
# 6           Manutenção Preventiva e Evolutiva Próton        47493.72
# 7  Bilhetes de passagens aéreas, reservas, emissã...       380574.23
# 8                         Apoio administrativo 1 e 2      2043582.72
# 9                       Assinatura do Jornal O Globo         1248.00
#
#    fk_empresa_contratada data_inicio_vigencia data_termino_vigencia
# 0                      1           2014-12-20            2015-12-19
# 1                      2           2015-02-26            2015-12-31
# 2                      3           2015-02-10            2015-12-31
# 3                      4           2015-01-01            2015-12-31
# 4                      5           2015-01-27            2016-01-26
# 5                      6           2015-01-28            2016-01-27
# 6                      7           2015-02-14            2016-02-13
# 7                      8           2015-02-25            2016-02-24
# 8                      9           2015-03-05            2016-03-04
# 9                     10           2015-03-18            2016-03-17

# %%
contratos_final_2['tempo_contrato'] = (contratos_final_2.data_termino_vigencia - contratos_final_2.data_inicio_vigencia).dt.days
contratos_final_2
# Out:
#      id_contrato nome_contrato  \
# 0              1       13/2012
# 1              2  Disp. Lic. 1
# 2              3  Disp. Lic. 2
# 3              4       32/2014
# 4              5      001/2014
# ..           ...           ...
# 179          180       13/2020
# 180          181      009/2018
# 181          182       16/2020
# 182          183       18/2020
# 183          184       20/2020
#
#                                        objeto_contrato  valor_contrato  \
# 0    Contratação de Empresa para Ministrar Curso de...        94947.23
# 1          Prestação de serviço na confecção de Chaves         5234.00
# 2        Prestação de serviço na confecção de Carimbos         1800.00
# 3                           Serviço de Telefônia Móvel        73915.08
# 4               Publicações no Diário Oficial da União        45000.00
# ..                                                 ...             ...
# 179  Contratação de serviços ofertados pelo SESI/Si...       134211.84
# 180   Serviços de Suporte Tecnológico ao Ambiente d...      2107768.42
# 181               Aquisição e Instalação de divisórias      5541773.00
# 182  Manutenção Preventiva e corretiva dos elevador...         9600.00
# 183         Contratação de Serviço comum de engenharia       102600.00
#
#      fk_empresa_contratada data_inicio_vigencia data_termino_vigencia  \
# 0                        1           2014-12-20            2015-12-19
# 1                        2           2015-02-26            2015-12-31
# 2                        3           2015-02-10            2015-12-31
# 3                        4           2015-01-01            2015-12-31
# 4                        5           2015-01-27            2016-01-26
# ..                     ...                  ...                   ...
# 179                     65           2020-07-24            2021-07-24
# 180                     17           2020-07-27            2021-07-27
# 181                     66           2020-08-19            2021-08-19
# 182                     67           2020-08-31            2021-08-31
# 183                     68           2020-09-08            2021-09-08
#
#      tempo_contrato
# 0               364
# 1               308
# 2               324
# 3               364
# 4               364
# ..              ...
# 179             365
# 180             365
# 181             365
# 182             365
# 183             365
#
# [184 rows x 8 columns]

# %%
contratos_final_2.nome_contrato.value_counts()
# Out:
# 004/16           5
# 42064            5
# 006/2015         5
# 005/2015         5
# 005/2016         4
#                 ..
# Disp. Lic. 24    1
# Disp. Lic. 23    1
# Disp. Lic. 22    1
# Disp. Lic. 21    1
# 20/2020          1
# Name: nome_contrato, Length: 122, dtype: int64

# %%
contratos_final_2[contratos_final_2.nome_contrato == '004/16']
# Out:
#      id_contrato nome_contrato                          objeto_contrato  \
# 49            50        004/16  Serviços de Telefonia Móvel (Celulares)
# 71            72        004/16  Serviços de Telefonia Móvel (Celulares)
# 99           100        004/16  Serviços de Telefonia Móvel (Celulares)
# 123          124        004/16  Serviços de Telefonia Móvel (Celulares)
# 167          168        004/16  Serviços de Telefonia Móvel (Celulares)
#
#      valor_contrato  fk_empresa_contratada data_inicio_vigencia  \
# 49          67461.0                      4           2016-05-01
# 71          67461.0                      4           2017-05-01
# 99          67461.0                      4           2019-05-01
# 123         67461.0                      4           2019-05-01
# 167         62780.6                      4           2020-05-01
#
#     data_termino_vigencia  tempo_contrato
# 49             2017-05-01             365
# 71             2018-05-01             365
# 99             2019-05-01               0
# 123            2020-05-01             366
# 167            2021-05-01             365

# %%
contratos_final_2.tempo_contrato.value_counts()
# Out:
#  365     88
#  366     45
#  364     10
#  1096     8
#  730      2
#  352      2
#  731      2
#  0        2
#  749      2
#  359      2
#  750      2
#  722      2
#  1095     2
#  729      2
#  350      1
#  531      1
#  179      1
#  182      1
# -2        1
#  340      1
#  353      1
#  363      1
#  324      1
#  339      1
#  308      1
#  394      1
#  295      1
# Name: tempo_contrato, dtype: int64

# %%
contratos_final_2 = contratos_final_2[contratos_final_2.tempo_contrato > 0]

# %%
contratos_final_2.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Carregamento dos Dados

# %%
credentials = service_account.Credentials.from_service_account_file(filename='/GBQ.json', scopes=["https://www.googleapis.com/auth/cloud-platform"])

# %%
contratos_final_2.to_gbq(credentials=credentials, destination_table='projectetl-401903.datasetETL.etl_csv', if_exists='replace', table_schema=[{'name':'data_inicio_vigencia', 'type':'DATE'},{'name':'data_termino_vigencia', 'type':'DATE'}])
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 422.05it/s]
